# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# dry beans data file
dry_df=pd.read_excel('/content/Dry_Bean_Dataset.xlsx')

# %%
# showing top5 rows to understand the data
dry_df.head()
# Out:
#     Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0  28395    610.291       208.178117       173.888747      1.197191
# 1  28734    638.018       200.524796       182.734419      1.097356
# 2  29380    624.110       212.826130       175.931143      1.209713
# 3  30008    645.884       210.557999       182.516516      1.153638
# 4  30140    620.134       201.847882       190.279279      1.060798
#
#    Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0      0.549812       28715     190.141097  0.763923  0.988856   0.958027
# 1      0.411785       29172     191.272750  0.783968  0.984986   0.887034
# 2      0.562727       29690     193.410904  0.778113  0.989559   0.947849
# 3      0.498616       30724     195.467062  0.782681  0.976696   0.903936
# 4      0.333680       30417     195.896503  0.773098  0.990893   0.984877
#
#    Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  Class
# ...

# %%
# Checking missing values
dry_df.isnull().sum()
# Out:
# Area               0
# Perimeter          0
# MajorAxisLength    0
# MinorAxisLength    0
# AspectRation       0
# Eccentricity       0
# ConvexArea         0
# EquivDiameter      0
# Extent             0
# Solidity           0
# roundness          0
# Compactness        0
# ShapeFactor1       0
# ShapeFactor2       0
# ShapeFactor3       0
# ShapeFactor4       0
# Class              0
# dtype: int64

# %%
# Datatypes
dry_df.dtypes
# Out:
# Area                 int64
# Perimeter          float64
# MajorAxisLength    float64
# MinorAxisLength    float64
# AspectRation       float64
# Eccentricity       float64
# ConvexArea           int64
# EquivDiameter      float64
# Extent             float64
# Solidity           float64
# roundness          float64
# Compactness        float64
# ShapeFactor1       float64
# ShapeFactor2       float64
# ShapeFactor3       float64
# ShapeFactor4       float64
# Class               object
# dtype: object

# %%
 # Target data distribution
import matplotlib.pyplot as plt
# Count the occurrences of each class
class_counts = dry_df['Class'].value_counts()
# Create a bar chart for the target variable 'Class'
plt.figure(figsize=(10, 6))
# Generate a list of unique colors for each class
colors = plt.cm.rainbow(np.linspace(0, 1, len(class_counts)))
class_counts.plot(kind='bar',color=colors)
plt.title('Distribution of Bean Classes')
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()
# Show the plot
plt.show()

# %%
dry_df.describe()
# Out:
#                 Area     Perimeter  MajorAxisLength  MinorAxisLength  \
# count   13611.000000  13611.000000     13611.000000     13611.000000
# mean    53048.284549    855.283459       320.141867       202.270714
# std     29324.095717    214.289696        85.694186        44.970091
# min     20420.000000    524.736000       183.601165       122.512653
# 25%     36328.000000    703.523500       253.303633       175.848170
# 50%     44652.000000    794.941000       296.883367       192.431733
# 75%     61332.000000    977.213000       376.495012       217.031741
# max    254616.000000   1985.370000       738.860153       460.198497
#
#        AspectRation  Eccentricity     ConvexArea  EquivDiameter        Extent  \
# count  13611.000000  13611.000000   13611.000000   13611.000000  13611.000000
# mean       1.583242      0.750895   53768.200206     253.064220      0.749733
# std        0.246678      0.092002   29774.915817      59.177120      0.049086
# ...

# %%
# Selecting numerical columns
dry_df1=dry_df.drop('Class',axis=1)

# %% [markdown]
# #### Heatmap

# %%
# Heatmap correlation
# Calculate the correlation matrix
corr_matrix = dry_df1.corr()

# Plot the heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm', cbar_kws={'shrink': .5}, square=True)
plt.title('Correlation Heatmap of Numeric Features')
plt.xticks(rotation=45)
plt.yticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
dry_df.describe()
# Out:
#                 Area     Perimeter  MajorAxisLength  MinorAxisLength  \
# count   13611.000000  13611.000000     13611.000000     13611.000000
# mean    53048.284549    855.283459       320.141867       202.270714
# std     29324.095717    214.289696        85.694186        44.970091
# min     20420.000000    524.736000       183.601165       122.512653
# 25%     36328.000000    703.523500       253.303633       175.848170
# 50%     44652.000000    794.941000       296.883367       192.431733
# 75%     61332.000000    977.213000       376.495012       217.031741
# max    254616.000000   1985.370000       738.860153       460.198497
#
#        AspectRation  Eccentricity     ConvexArea  EquivDiameter        Extent  \
# count  13611.000000  13611.000000   13611.000000   13611.000000  13611.000000
# mean       1.583242      0.750895   53768.200206     253.064220      0.749733
# std        0.246678      0.092002   29774.915817      59.177120      0.049086
# ...

# %%
dry_df1=dry_df.drop('Class',axis=1)

# %%
dry_df1.skew()
# Out:
# Area               2.952931
# Perimeter          1.626124
# MajorAxisLength    1.357815
# MinorAxisLength    2.238211
# AspectRation       0.582573
# Eccentricity      -1.062824
# ConvexArea         2.941821
# EquivDiameter      1.948958
# Extent            -0.895348
# Solidity          -2.550093
# roundness         -0.635749
# Compactness        0.037115
# ShapeFactor1      -0.534141
# ShapeFactor2       0.301226
# ShapeFactor3       0.242481
# ShapeFactor4      -2.759483
# dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Select only the numeric columns
numeric_cols = dry_df.select_dtypes(include=[np.number]).columns.tolist()
# Create density plots
num_plots = len(numeric_cols)
num_rows = num_plots // 2 if num_plots % 2 == 0 else (num_plots // 2) + 1
plt.figure(figsize=(12, num_rows * 4))
for index, col in enumerate(numeric_cols):
    plt.subplot(num_rows, 2, index + 1)
    sns.kdeplot(data=dry_df, x=col, fill=True)
    plt.title(f'Density Plot of {col}')
    plt.xlabel(col)
    plt.ylabel('Density')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Data preprocessing
# * Normalization on numerical variables
# * Transforming categorical to numerical

# %%
dry_df.columns
# Out:
# Index(['Area', 'Perimeter', 'MajorAxisLength', 'MinorAxisLength',
#        'AspectRation', 'Eccentricity', 'ConvexArea', 'EquivDiameter', 'Extent',
#        'Solidity', 'roundness', 'Compactness', 'ShapeFactor1', 'ShapeFactor2',
#        'ShapeFactor3', 'ShapeFactor4', 'Class'],
#       dtype='object')

# %%
# Normalization
from sklearn.preprocessing import StandardScaler
features = [
    'Area', 'Perimeter', 'MajorAxisLength', 'MinorAxisLength',
    'AspectRation', 'Eccentricity', 'ConvexArea', 'EquivDiameter', 'Extent',
    'Solidity', 'roundness', 'Compactness', 'ShapeFactor1', 'ShapeFactor2',
    'ShapeFactor3', 'ShapeFactor4'
]

# Initialize the StandardScaler
scaler = StandardScaler()

# Fit the scaler to the data and transform it
dry_df[features] = scaler.fit_transform(dry_df[features])

# %%
from sklearn.preprocessing import LabelEncoder
# Initialize the LabelEncoder
label_encoder = LabelEncoder()
# Fit Label Encoder and transform the 'Class' column
dry_df['Class'] = label_encoder.fit_transform(dry_df['Class'])

# checking labels how they are encoded
mapping = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
print("Label encoding mapping:", mapping)
# Out:
# Label encoding mapping: {'BARBUNYA': 0, 'BOMBAY': 1, 'CALI': 2, 'DERMASON': 3, 'HOROZ': 4, 'SEKER': 5, 'SIRA': 6}

# %% [markdown]
# ##### Dividing the dataset into X and Y

# %%
# Storing independent variables into X
X=dry_df.drop('Class',axis=1)
# Storing Target variable into Y
Y=dry_df['Class']

# %% [markdown]
# #### Splitting Train and Test data

# %%
from sklearn.model_selection import train_test_split

# Split the data into training and testing sets with an 80/20 ratio
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.20, random_state=42)

# Display the shape of the train and test sets to verify the sizes
print("Training set shape for X:", X_train.shape)
print("Testing set shape for X:", X_test.shape)
print("Training set shape for Y:", Y_train.shape)
print("Testing set shape for Y:", Y_test.shape)
# Out:
# Training set shape for X: (10888, 16)
# Testing set shape for X: (2723, 16)
# Training set shape for Y: (10888,)
# Testing set shape for Y: (2723,)

# %% [markdown]
# #### Machine learning algorithms
# * Training the models
# * Evaluating the model performance

# %%
import warnings
# Ignore all warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, f1_score
# Dictionary of models
models = {
    "Logistic Regression": LogisticRegression(random_state=12),
    "KNN Classifier": KNeighborsClassifier(),
    "SVM Classifier": SVC(random_state=12),
    "Naive Bayes Classifier": GaussianNB(),
    "Decision Tree": DecisionTreeClassifier(random_state=12),
    "Random Forest": RandomForestClassifier(random_state=12),
    "XGBoost Classifier": XGBClassifier(random_state=12)
}

# Train and evaluate each model
results = {}
for name, model in models.items():
    model.fit(X_train, Y_train)
    predictions = model.predict(X_test)
    accuracy = accuracy_score(Y_test, predictions)
    f1 = f1_score(Y_test, predictions, average='weighted')
    results[name] = {"Accuracy": accuracy, "F1 Score": f1}

# Output the results
for model_name, metrics in results.items():
    print(f"{model_name} - Accuracy: {metrics['Accuracy']:.2f}, F1 Score: {metrics['F1 Score']:.2f}")
# Out:
# Logistic Regression - Accuracy: 0.93, F1 Score: 0.93
# KNN Classifier - Accuracy: 0.92, F1 Score: 0.92
# SVM Classifier - Accuracy: 0.93, F1 Score: 0.93
# Naive Bayes Classifier - Accuracy: 0.90, F1 Score: 0.90
# Decision Tree - Accuracy: 0.89, F1 Score: 0.89
# Random Forest - Accuracy: 0.93, F1 Score: 0.93
# XGBoost Classifier - Accuracy: 0.93, F1 Score: 0.93

# %% [markdown]
# #### Evaluating using Cross-validation

# %%
from sklearn.model_selection import cross_val_score, KFold
from sklearn.metrics import make_scorer, f1_score, accuracy_score
#  cross-validation
cv = KFold(n_splits=5, random_state=42, shuffle=True)

# D f1 score to handle multi-class classification
f1_scorer = make_scorer(f1_score, average='weighted')

# Dictionary to store scores
cv_scores = {}

# Evaluate each model using cross-validation
for name, model in models.items():
    f1_scores = cross_val_score(model, X, Y, scoring=f1_scorer, cv=cv, n_jobs=-1)
    accuracy_scores = cross_val_score(model, X, Y, scoring='accuracy', cv=cv, n_jobs=-1)
    cv_scores[name] = {
        'Mean Accuracy': accuracy_scores.mean(),
        'Accuracy Std Deviation': accuracy_scores.std(),
        'Mean F1 Score': f1_scores.mean(),
        'F1 Score Std Deviation': f1_scores.std()
    }

cv_scores
# Out:
# {'Logistic Regression': {'Mean Accuracy': 0.9243257763148061,
#   'Accuracy Std Deviation': 0.0027821011921482118,
#   'Mean F1 Score': 0.9244377540619355,
#   'F1 Score Std Deviation': 0.003056070462950402},
#  'KNN Classifier': {'Mean Accuracy': 0.9219013044511837,
#   'Accuracy Std Deviation': 0.0025545635437805945,
#   'Mean F1 Score': 0.921961643022232,
#   'F1 Score Std Deviation': 0.002720316870110591},
#  'SVM Classifier': {'Mean Accuracy': 0.9304236666834862,
#   'Accuracy Std Deviation': 0.004745981693648107,
#   'Mean F1 Score': 0.9305060300550853,
#   'F1 Score Std Deviation': 0.004928971396974891},
#  'Naive Bayes Classifier': {'Mean Accuracy': 0.8967006772525549,
#   'Accuracy Std Deviation': 0.004470849392561526,
#   'Mean F1 Score': 0.8968238500566775,
#   'F1 Score Std Deviation': 0.0046156673612975565},
#  'Decision Tree': {'Mean Accuracy': 0.8960402622447958,
#   'Accuracy Std Deviation': 0.00405659329638042,
#   'Mean F1 Score': 0.8960726616895837,
# ...

# %% [markdown]
# ### Hyperparameter tuning
# * GridsearchCv

# %%
from sklearn.model_selection import GridSearchCV
# Define the parameter grid for SVM
param_grid_svm = {
    'C': [1, 10],
    'gamma': ['scale'],
    'kernel': ['rbf', 'linear', 'poly']
}

# Adjusted parameter grid for XGBoost
param_grid_xgb = {
    'n_estimators': [100],
    'max_depth': [3],
    'learning_rate': [0.2,0.3,0.4,0.5]
}
cv_kfold=KFold(n_splits=5, random_state=42, shuffle=True)
# Initialize the classifiers
svm_model = SVC(random_state=12)
xgb_model = XGBClassifier(random_state=12)

# Setup the GridSearchCV for SVM
grid_search_svm = GridSearchCV(estimator=svm_model, param_grid=param_grid_svm,
                               scoring='accuracy', cv=cv_kfold, verbose=1, n_jobs=-1)

# Setup the GridSearchCV for XGBoost
grid_search_xgb = GridSearchCV(estimator=xgb_model, param_grid=param_grid_xgb,
                               scoring='accuracy', cv=cv_kfold, verbose=1, n_jobs=-1)

# Fit the grid search to the data
print("Tuning SVM...")
grid_search_svm.fit(X, Y)
print("Best parameters for SVM:", grid_search_svm.best_params_)
print("Best score for SVM:", grid_search_svm.best_score_)

print("Tuning XGBoost...")
grid_search_xgb.fit(X, Y)
print("Best parameters for XGBoost:", grid_search_xgb.best_params_)
print("Best score for XGBoost:", grid_search_xgb.best_score_)
# Out:
# Tuning SVM...
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Best parameters for SVM: {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# Best score for SVM: 0.9325543989036167
# Tuning XGBoost...
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# Best parameters for XGBoost: {'learning_rate': 0.2, 'max_depth': 3, 'n_estimators': 100}
# Best score for XGBoost: 0.9277789845286147

# %%
# Adjusted parameter grid for XGBoost
param_grid_xgb = {
    'n_estimators': [500],
    'max_depth': [3,10],
    'learning_rate': [0.2,0.3,0.4,0.5]
}
xgb_model = XGBClassifier(random_state=12)

# Setup the GridSearchCV for XGBoost
grid_search_xgb = GridSearchCV(estimator=xgb_model, param_grid=param_grid_xgb,
                               scoring='accuracy', cv=cv_kfold, verbose=1, n_jobs=-1)

print("Tuning XGBoost...")
grid_search_xgb.fit(X, Y)
print("Best parameters for XGBoost:", grid_search_xgb.best_params_)
print("Best score for XGBoost:", grid_search_xgb.best_score_)
# Out:
# Tuning XGBoost...
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# Best parameters for XGBoost: {'learning_rate': 0.2, 'max_depth': 3, 'n_estimators': 500}
# Best score for XGBoost: 0.9260889427234679

# %%
# selecting best parametres
xgb_model = XGBClassifier(random_state=12,learning_rate=0.2,
                          max_depth= 3, n_estimators=100)
xgb_model.fit(X,Y)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.2, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
# Extract feature importances
xgb_importances = xgb_model.feature_importances_

# Create a DataFrame for the feature importances
features_df = pd.DataFrame({
    'Feature': X.columns,
    'Importance': xgb_importances
})

# Sort the DataFrame by importance
features_df = features_df.sort_values(by='Importance', ascending=False)

# Plotting
plt.figure(figsize=(10, 6))
plt.bar(features_df['Feature'], features_df['Importance'], color='skyblue')
plt.title('XGBoost Feature Importances')
plt.xlabel('Features')
plt.ylabel('Importance')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Feature selection

# %%
features_df
# Out:
#             Feature  Importance
# 11      Compactness    0.306140
# 0              Area    0.162177
# 6        ConvexArea    0.142418
# 12     ShapeFactor1    0.111478
# 2   MajorAxisLength    0.070946
# 1         Perimeter    0.068458
# 13     ShapeFactor2    0.039196
# 3   MinorAxisLength    0.033173
# 10        roundness    0.029832
# 15     ShapeFactor4    0.014174
# 4      AspectRation    0.009253
# 9          Solidity    0.009098
# 8            Extent    0.003656
# 5      Eccentricity    0.000000
# 7     EquivDiameter    0.000000
# 14     ShapeFactor3    0.000000
